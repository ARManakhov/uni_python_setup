# %%
# !pip install 'git+https://github.com/facebookresearch/detectron2.git'
# Out:
# Collecting git+https://github.com/facebookresearch/detectron2.git
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-req-build-qkkfj7e2
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-req-build-qkkfj7e2
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 0ae803b1449cd2d3f8fa1b7c0f59356db10b3083
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (10.3.0)
# Requirement already satisfied: matplotlib in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (3.8.4)
# Requirement already satisfied: pycocotools>=2.0.2 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (2.4.0)
# Requirement already satisfied: yacs>=0.1.8 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (3.0.0)
# Requirement already satisfied: tqdm>4.29.0 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (4.66.4)
# Requirement already satisfied: tensorboard in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (2.16.2)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (2.3.0)
# Requirement already satisfied: hydra-core>=1.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (1.3.2)
# Requirement already satisfied: black in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (24.4.2)
# Requirement already satisfied: packaging in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from detectron2==0.6) (24.0)
# Requirement already satisfied: numpy in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (1.26.4)
# Requirement already satisfied: pyyaml>=5.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.1)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from matplotlib->detectron2==0.6) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from matplotlib->detectron2==0.6) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from matplotlib->detectron2==0.6) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from matplotlib->detectron2==0.6) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from matplotlib->detectron2==0.6) (2.9.0.post0)
# Requirement already satisfied: click>=8.0.0 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from black->detectron2==0.6) (8.1.7)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from black->detectron2==0.6) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from black->detectron2==0.6) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from black->detectron2==0.6) (4.2.1)
# Requirement already satisfied: absl-py>=0.4 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from tensorboard->detectron2==0.6) (2.1.0)
# Requirement already satisfied: grpcio>=1.48.2 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from tensorboard->detectron2==0.6) (1.63.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from tensorboard->detectron2==0.6) (3.6)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from tensorboard->detectron2==0.6) (4.25.3)
# Requirement already satisfied: setuptools>=41.0.0 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from tensorboard->detectron2==0.6) (69.5.1)
# Requirement already satisfied: six>1.9 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from tensorboard->detectron2==0.6) (1.16.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from tensorboard->detectron2==0.6) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/sirosh/Documents/prog/python_projects/uni_python_setup/.venv/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (2.1.5)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import torch, detectron2
# !nvcc --version
TORCH_VERSION = ".".join(torch.__version__.split(".")[:2])
CUDA_VERSION = torch.__version__.split("+")[-1]
print("torch: ", TORCH_VERSION, "; cuda: ", CUDA_VERSION)
print("detectron2:", detectron2.__version__)
# Out:
# zsh:1: command not found: nvcc
# torch:  2.3 ; cuda:  cu121
# detectron2: 0.6

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger

setup_logger()

# import some common libraries
import numpy as np
import os, json, cv2, random
import matplotlib.pyplot as plt

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog

# %% [markdown]
# # Run a pre-trained detectron2 model

# %%
# !wget http://images.cocodataset.org/val2017/000000439715.jpg -q -O input.jpg
im = cv2.imread("./input.jpg")

# %%
cfg = get_cfg()
# add project-specific config (e.g., TensorMask) here if you're not running a model in detectron2's core library
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
# Find a model from detectron2's model zoo. You can use the https://dl.fbaipublicfiles... url as well
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
predictor = DefaultPredictor(cfg)
outputs = predictor(im)
# Out:
# [05/13 23:54:36 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...

# %%
# We can use `Visualizer` to draw the predictions on the image.
v = Visualizer(im[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
plt.imshow(out.get_image()[:, :, ::-1])
